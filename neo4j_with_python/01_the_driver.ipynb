# %% [markdown]
# # Using Neo4j with Python - The Driver

# %% [markdown]
# ## 1) Installing the driver

# %%
# !pip install neo4j
# Out:
# Requirement already satisfied: neo4j in /home/francisco/Documentos/neo4j-formation/venv/lib/python3.14/site-packages (6.2.0)
# Requirement already satisfied: pytz in /home/francisco/Documentos/neo4j-formation/venv/lib/python3.14/site-packages (from neo4j) (2026.2)

# %% [markdown]
# ## 2) Creating a Driver instance

# %%
from neo4j import GraphDatabase

driver = GraphDatabase.driver(
    "bolt://localhost:7687",
    auth=("neo4j", "Camp6hex192994")
)

# %% [markdown]
# ## 3) Verifying Connectivity

# %%
driver.verify_connectivity()

# %% [markdown]
# ## 4) Running the first query

# %%
records, summary, keys = driver.exe ### CONTINUA AQUI
